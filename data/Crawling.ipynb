# %% [markdown]
# 참고: https://velog.io/@xenrose/naverShppingReviewCrawling
# chromedriver.exe 설치: https://ddingmin00.tistory.com/entry/mac-m1-%EC%9B%B9-%ED%81%AC%EB%A1%A4%EB%A7%81-Selenium-Chromedriver-%EC%84%A4%EC%B9%98%ED%95%98%EA%B8%B0

# %% [raw]
# pip install selenium==4.2.0
# pip install numpy==1.23.0
# pip install pandas==2.0.3
# pip install konlpy==0.6.0
# pip install matplotlib==3.6.0
# pip install seaborn==0.12.1
# pip install wordcloud==1.9.2

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from time import sleep
import pandas as pd
import numpy as np
import konlpy
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import PIL

# %%
### 제품명 및 사이트
# 해남 꿀 고구마 3kg 5kg 호박고구마 베니하루카 [원산지:국산(전라남도 해남군)]
pd24 = 'https://smartstore.naver.com/mggfood/products/252144123?NaPm=ct%3Dlutv0ldk%7Cci%3D63ec2dd77572f51356e562c848a1b8ecc6c7d0bb%7Ctr%3Dslcc%7Csn%3D239741%7Chk%3D6d3ed66fe63e9236fdf30b13a21083d516559413'

# 1kg 원두 커피 베트남 로부스타 블루드래곤 워시드 G1 홀빈 원두콩 맛있는 고소한 당일 로스팅 [원산지:베트남]
pd25 = 'https://smartstore.naver.com/blackbeans/products/310288062?NaPm=ct%3Dlutvfqwg%7Cci%3D078588bc09a3d886277e5288ae2f73824dd88c3f%7Ctr%3Dslcc%7Csn%3D204014%7Chk%3Dbfff6220ff2c3c31e7ba5343814300da6f29f4a2'

# 내츄럴 가정용 재활용 분리수거함 35L 대용량 분리수거통 쓰레기통
pd26 = 'https://smartstore.naver.com/n-plastic/products/4199487647?NaPm=ct%3Dlutvifco%7Cci%3Dfe800798b65588a117c5c4afd2e4eb04f8e7f089%7Ctr%3Dslcc%7Csn%3D157790%7Chk%3D810059a3243f211dcb4409db31c51f664dd29a7c'

# 내아이애 아기과자 유기농 떡뻥 백미 쌀과자 외 43종 [원산지:상세 설명에 표시]
pd27 = 'https://smartstore.naver.com/myilove/products/379669149?NaPm=ct%3Dlutvvwow%7Cci%3D42a0cef69df0cc17a8ad1ae68e5d04d395a41f18%7Ctr%3Dslcc%7Csn%3D355970%7Chk%3D267e47e67492ccb783093affe1ab5e8d9f8d29d4'

# 닥터바이오 온가족용 에코 로션 500g 아기 유아 성인 바디 페이스 보습로션
pd28 = 'https://brand.naver.com/doctorbio/products/4072544295?NaPm=ct%3Dlutvwqs8%7Cci%3D285ea840ea52917225808531bff91e721b0050c3%7Ctr%3Dslcc%7Csn%3D721498%7Chk%3D48bdfb22a24f6099de337c363504f7cefe2d28bb'

# 아기 양말 아동 신생아 양말 유아 어린이 봄 여름 골지 양말 세트
pd29 = 'https://smartstore.naver.com/ggomisocks/products/503074444?NaPm=ct%3Dlutvxn6w%7Cci%3D454434dbc4a6df2fe421631e6049b65d1d268030%7Ctr%3Dslcc%7Csn%3D256395%7Chk%3Dd7890b15ed7f0d8841ac03a61d5b5c65e16499df'

# 멜킨 마운틴 스텝퍼 하체 실내 유산소 계단오르기 걷기 운동효과 스텝밀 기구
pd30 = 'https://brand.naver.com/melkin/products/4731396796?NaPm=ct%3Dlutvyvy0%7Cci%3Deac7f6e24b92702a8f109cd941a4dc81f90f2520%7Ctr%3Dslcc%7Csn%3D447572%7Chk%3De36fd9d87cd561465188e7b8bf56d3bf60c2a4d9'

# 보르르 분유포트
pd31 = 'https://brand.naver.com/boleuleu/products/4770915416?NaPm=ct%3Dlutw2f9c%7Cci%3D0f27c036463865a4728928c7eb99c323a3c94de7%7Ctr%3Dslcc%7Csn%3D982560%7Chk%3D55cf22aac2240ac502cc52a60740761f81756760'

# 오아 무드1000 미니 가습기 초음파 소형 간편세척 신생아 캠핑 원룸 세척편한 통세척
pd32 = 'https://brand.naver.com/oastore/products/486974668?NaPm=ct%3Dlutw39co%7Cci%3Dfca982300d272192314f9808fc0c69815f7f7b31%7Ctr%3Dslcc%7Csn%3D256847%7Chk%3Dec3a4778e653d37fc40fbab36ca16a110e062bbb'

# 한일전자 2300W 드라이기 전문가용 고출력 헤어드라이기 추천 헤어드라이어, PD-H4300
pd33 = 'https://smartstore.naver.com/hanilpatech/products/2795891163?NaPm=ct%3Dlutw3rvc%7Cci%3D7608b56e31fe2721c6639ea8d22f825e32aff26e%7Ctr%3Dslcc%7Csn%3D162718%7Chk%3Ddd022e25cfb21b0ec7dc39e9b5b9f6985fc80675'

# 택배박스 3SK box 가로 120~220mm B103(160x160x160)
pd34 = 'https://smartstore.naver.com/3skcokr/products/107922131?NaPm=ct%3Dlutw4l6w%7Cci%3D200207edbc5c19a322482763ab3e0a733090b13a%7Ctr%3Dslcc%7Csn%3D168406%7Chk%3D8d0812f4d635777b44bf8d7ac06d3b466244b749'

# 국산 안전 접지 멀티탭 개별 과부하차단 멀티콘센트 4구 1.5M
pd35 = 'https://brand.naver.com/ijung/products/2107300097?NaPm=ct%3Dlutw5940%7Cci%3D7880809dcd373303229f416ac9638a3ba154e15e%7Ctr%3Dslcc%7Csn%3D304871%7Chk%3D28d150aaa58bbdf53a667bbdc3c59858086487f4'

# 만년도장 결재 법인 직인 인감 아크릴4푼검정
pd36 = 'https://smartstore.naver.com/topstamp/products/380893995?NaPm=ct%3Dlutw6d8g%7Cci%3Dd87a3db61f0b9930316833059d5717855288322b%7Ctr%3Dslcc%7Csn%3D353274%7Chk%3D39b4233a9bacd189b4e34ec911b587ee346d32a1'

# %%
target_url = pd26
new_value = '내*럴 가정용 재활용 분리수거함'
next_page_count = 100 # 1 당 10페이지 / 최소 1 이상
sleepDelay = 1 # 컴퓨터 성능에 따라 1~3 권장
df = pd.DataFrame(columns=['ReviewScore', 'RawText'])
df_idx = 0

# %%
browser = webdriver.Chrome(service= Service(ChromeDriverManager().install()))
sleep(sleepDelay * 3)
browser.get(target_url)
sleep(sleepDelay)

# %%
# 크롬 창이 뜨면 '리뷰' 부분을 찾아 SELECTOR 복사
browser.find_element(By.CSS_SELECTOR, '#_productFloatingTab > div > div._27jmWaPaKy._1dDHKD1iiX > ul > li:nth-child(2) > a').click()
sleep(sleepDelay * 2)

# %% [markdown]
# ### 평점 낮은순 크롤링

# %%
# 기본이 랭킹순이라서 '평점 낮은순' 눌르고 시작 
browser.find_element(By.CSS_SELECTOR, '#REVIEW > div > div._2LvIMaBiIO > div._2LAwVxx1Sd > div._1txuie7UTH > ul > li:nth-child(4) > a').click()
sleep(sleepDelay * 2)

# %%
# 실질적인 크롤링이 진행되는 부분
next_list_count = 1000

while next_list_count > 0: 

    for page in range(2, 12): # 1~ 10페이지 반복문
        try: 
            browser.find_element(By.CSS_SELECTOR, f'#REVIEW > div > div._2LvIMaBiIO > div._2g7PKvqCKe > div > div > a:nth-child({str(page)})').click() # 각 페이지 클릭
            sleep(sleepDelay) 

            for review_number in range(1,20+1): # 리뷰 1페이지당 최대 20개의 리뷰가 있음. 
                
                # 아래 코드가 실제 리뷰를 크롤링하는 코드임.
                review_table = browser.find_elements(By.CSS_SELECTOR, f'#REVIEW > div > div._2LvIMaBiIO > div._2g7PKvqCKe > ul > li:nth-child({str(review_number)})')
                for review in review_table:
                    df.loc[df_idx] = [review.find_element(By.CSS_SELECTOR, f'div._3i1mVq_JBd > div._3HKlxxt8Ii > div._2V6vMO_iLm > em').text,
                                      review.find_element(By.CSS_SELECTOR, f'div._3z6gI4oI6l').text] # 코드를 크롤링 하여 DataFrame에 넣음.
                    df_idx += 1
                    
        except: # 10페이지까지 없는 경우 오류를 발생시키므로 더이상의 반복문은 무의미해서 반복문 탈출
            print("마지막 페이지")
            break

    try: 
        browser.find_element(By.CSS_SELECTOR, f'#REVIEW > div > div._2LvIMaBiIO > div._2g7PKvqCKe > div > div > a.fAUKm1ewwo._2Ar8-aEUTq._nlog_click').click() # [다음 >] 클릭
        next_list_count -= 1 # 사용자가 미리 설정한 list_count임. 
        sleep(sleepDelay)

    except: # 리뷰의 마지막 페이지까지 올 경우 [다음 >] 버튼이 없으므로 오류 발생함. 더이상의 반복은 무의미하므로 반복문 탈출
        print("마지막 목록")
        break
# Out:
# 마지막 페이지
# 마지막 목록

# %%
df_low = df
df_low['ProductName'] = new_value

# %%
df_low
# Out:
#      ReviewScore                                            RawText  \
# 0              1                                한달사용기무겁고 불편해서 나눔했어요
# 1              1                                한달사용기무겁고 불편해서 나눔했어요
# 2              1                                     마감이 너무 불량입니다..
# 3              1                     마감이 너무 불량입니다...실제로 보면 더 심하네요.ㅡ
# 4              1                                포장좀 꼼꼼히 하셔야 할 것 같네요
# ...          ...                                                ...
# 9382           4                       재구매베이지가 아니라 그레이가 온 줄 알았어요 ㅎㅎ
# 9383           4                           크기도 넉넉하고 깨끗합니다\n손잡이는 없어요
# 9384           4                        깨끗하고 크기도 좋아요\n손잡이가 없어서 아쉬워요
# 9385           4  생각보다 튼튼하구요 , 쓰레기가 들어있지않으면 좀가볍지만 쓴느데는 지장이없을 것같습...
# 9386           4                            깨끗해요 깔끔하고... 스티커가 떨어져서.
#
#             ProductName
# 0     내*럴 가정용 재활용 분리수거함
# 1     내*럴 가정용 재활용 분리수거함
# 2     내*럴 가정용 재활용 분리수거함
# 3     내*럴 가정용 재활용 분리수거함
# ...

# %% [markdown]
# ### 평점 높은순 크롤링

# %%
# 기본이 랭킹순이라서 '평점 높은순' 눌르고 시작 
browser.find_element(By.CSS_SELECTOR, '#REVIEW > div > div._2LvIMaBiIO > div._2LAwVxx1Sd > div._1txuie7UTH > ul > li:nth-child(3) > a').click()
sleep(sleepDelay * 2)

# %%
# 실질적인 크롤링이 진행되는 부분
next_list_count = 1000

while next_list_count > 0: 

    for page in range(2, 12): # 1~ 10페이지 반복문
        try: 
            browser.find_element(By.CSS_SELECTOR, f'#REVIEW > div > div._2LvIMaBiIO > div._2g7PKvqCKe > div > div > a:nth-child({str(page)})').click() # 각 페이지 클릭
            sleep(sleepDelay) 

            for review_number in range(1,20+1): # 리뷰 1페이지당 최대 20개의 리뷰가 있음. 
                
                # 아래 코드가 실제 리뷰를 크롤링하는 코드임.
                review_table = browser.find_elements(By.CSS_SELECTOR, f'#REVIEW > div > div._2LvIMaBiIO > div._2g7PKvqCKe > ul > li:nth-child({str(review_number)})')
                for review in review_table:
                    df.loc[df_idx] = [review.find_element(By.CSS_SELECTOR, f'div._3i1mVq_JBd > div._3HKlxxt8Ii > div._2V6vMO_iLm > em').text,
                                      review.find_element(By.CSS_SELECTOR, f'div._3z6gI4oI6l').text] # 코드를 크롤링 하여 DataFrame에 넣음.
                    df_idx += 1
                    
        except: # 10페이지까지 없는 경우 오류를 발생시키므로 더이상의 반복문은 무의미해서 반복문 탈출
            print("마지막 페이지")
            break

    try: 
        browser.find_element(By.CSS_SELECTOR, f'#REVIEW > div > div._2LvIMaBiIO > div._2g7PKvqCKe > div > div > a.fAUKm1ewwo._2Ar8-aEUTq._nlog_click').click() # [다음 >] 클릭
        next_list_count -= 1 # 사용자가 미리 설정한 list_count임. 
        sleep(sleepDelay)

    except: # 리뷰의 마지막 페이지까지 올 경우 [다음 >] 버튼이 없으므로 오류 발생함. 더이상의 반복은 무의미하므로 반복문 탈출
        print("마지막 목록")
        break
# Out:
# 마지막 페이지
# 마지막 목록

# %%
df_high = df
df_high['ProductName'] = new_value

# %%
df_high
# Out:
#      ReviewScore                                            RawText  \
# 0              5                                         굿굿  너무 좋아요
# 1              5                              한달사용기수납이나 재활용용으로지ㅡㅎ아요
# 2              5                    깔끔합니다. 제품 좋습니다.3개 쌓아도 높이 적당합니다.
# 3              5                                         진작살걸 그랬어요!
# 4              5                                    분리수거 할때마다 기분좋아요
# ...          ...                                                ...
# 9355           5  분리수거함 잘못하면 인테리어 망치고 지저분할거 같아 인터넷에서 온갖 상품들 다 찾아...
# 9356           5  분리수거함 잘못하면 인테리어 망치고 지저분할거 같아 인터넷에서 온갖 상품들 다 찾아...
# 9357           5                       튼튼해보이고 손잡이 있는 전용 봉투 활용도 좋아요.
# 9358           5                    배송도 빠르고, 구성도 잘 도착했습니다.\n튼튼해보여요.
# 9359           5  재활용을 오래 놔두기싫어 일부러 작은 용량으로 구매했는데, 절대 작지않네요~^^\n...
#
#             ProductName
# 0     내*럴 가정용 재활용 분리수거함
# 1     내*럴 가정용 재활용 분리수거함
# 2     내*럴 가정용 재활용 분리수거함
# 3     내*럴 가정용 재활용 분리수거함
# ...

# %%
merged_df = pd.concat([df_low, df_high], axis=0)
merged_df
# Out:
#      ReviewScore                                            RawText  \
# 0              1                                한달사용기무겁고 불편해서 나눔했어요
# 1              1                                한달사용기무겁고 불편해서 나눔했어요
# 2              1                                     마감이 너무 불량입니다..
# 3              1                     마감이 너무 불량입니다...실제로 보면 더 심하네요.ㅡ
# 4              1                                포장좀 꼼꼼히 하셔야 할 것 같네요
# ...          ...                                                ...
# 9355           5  분리수거함 잘못하면 인테리어 망치고 지저분할거 같아 인터넷에서 온갖 상품들 다 찾아...
# 9356           5  분리수거함 잘못하면 인테리어 망치고 지저분할거 같아 인터넷에서 온갖 상품들 다 찾아...
# 9357           5                       튼튼해보이고 손잡이 있는 전용 봉투 활용도 좋아요.
# 9358           5                    배송도 빠르고, 구성도 잘 도착했습니다.\n튼튼해보여요.
# 9359           5  재활용을 오래 놔두기싫어 일부러 작은 용량으로 구매했는데, 절대 작지않네요~^^\n...
#
#             ProductName
# 0     내*럴 가정용 재활용 분리수거함
# 1     내*럴 가정용 재활용 분리수거함
# 2     내*럴 가정용 재활용 분리수거함
# 3     내*럴 가정용 재활용 분리수거함
# ...

# %% [raw]
# df11 = pd.read_csv(f'Crawling/{new_value}.csv'); df11

# %% [raw]
# merged_df = pd.concat([df11, df_high], axis=0)
# merged_df

# %%
merged_df.to_csv(f'Crawling/{new_value}.csv', encoding='utf-8-sig') # csv로 저장할 경우 사용할것.
print("크롤링 완료")
# Out:
# 크롤링 완료

# %% [markdown]
# ---

# %% [raw]
# ### 제품명 및 사이트
# # 무지 반팔 티셔츠 긴팔 흰티 면티 흰색
# pd1 = 'https://smartstore.naver.com/nande/products/477282453?NaPm=ct%3Dlu7ybs68%7Cci%3D66977cf95ef2c80b62cee40b8e9565884b1e07ee%7Ctr%3Dslcc%7Csn%3D390548%7Chk%3D7b529d2b002a1e49c2677f999e698f837132ee3b'
#
# # 에이센트 네이처 디퓨저 200ml 화장실 실내방향제 집들이선물 그린에어리
# pd2 = 'https://brand.naver.com/ascent/products/2962547345?NaPm=ct%3Dlu7whty0%7Cci%3Dce209a69acbbe6f7bc8d2b3dcebd2e84ab1ab558%7Ctr%3Dslcc%7Csn%3D717942%7Chk%3D4c8715cb4f904147a371cf5e603ba64e3c47d24c'
#
# # 해오름 덴탈마스크 일회용 마스크 KF-AD 3중 대형 흰색 50매 비말
# pd3 = 'https://smartstore.naver.com/jeongpro/products/5000473803?NaPm=ct%3Dlu7yogyo%7Cci%3Db7f844c01e5c589fccef19501619d9c8a6a782b5%7Ctr%3Dslcc%7Csn%3D709640%7Chk%3Dc8999d4f02b234365ee7283d797ed36079a7f943'
#
# # 최대 34% / 달바 옐로우 미스트 세럼 100mlX2개
# pd4 = 'https://brand.naver.com/dalba/products/2029835017?NaPm=ct%3Dlu71gw2g%7Cci%3D4adaa26ce663af0476bad97b6b83f21c615ee3d6%7Ctr%3Dslsf%7Csn%3D441144%7Chk%3D1e5e7917e4184628f8b64d2908cbdb2642c7d9aa'
#
# # 우먼스9999 애플워치 스트랩 8 7 6 SE 2 호환 밀레니즈 루프 밴드 줄 시계줄 줄질 애플워치9스트랩
# pd5 = 'https://brand.naver.com/w9999/products/5172684672?NaPm=ct%3Dlu7ykmug%7Cci%3D51ddf934cc0f4bdc4df61c0d192525899a85c806%7Ctr%3Dslcc%7Csn%3D649561%7Chk%3Da01579fa769dcbdddc1808940e49b64064c095f7'
#
# # 절대콜라겐 프랑스 저분자 피쉬 콜라겐 펩타이드 고함량 먹는 어린 가루 150g
# pd6 = 'https://smartstore.naver.com/remora/products/2024404149?NaPm=ct%3Dlu70ili0%7Cci%3Daddced3598d0c9e90b3a15bc2d2f67a72c401852%7Ctr%3Dslcc%7Csn%3D243789%7Chk%3Dba38a0b73491dbfa4a3f1a614dc955203a595223'
#
# # 정직한패드 소형 400매 애견 강아지 배변패드 20g 반려견패드 박스포장
# pd7 = 'https://brand.naver.com/honestpad/products/609511054?NaPm=ct%3Dlu7yhujc%7Cci%3Dad6da390afb21f1af93cc05dbe995fed697b8f3a%7Ctr%3Dslcc%7Csn%3D435112%7Chk%3D3e571eeb0adc9c64e20f80d2e4b01b1b57aed77f'
#
# # 핫앤핫 프리미엄 핫팩(RED) 국내 직접생산 최신제조FDA ISO14001(환경)포켓용
# pd8 = 'https://smartstore.naver.com/hotnhot/products/120502182?NaPm=ct%3Dlu7wkxts%7Cci%3D4adf197ed4ca3b358b067f81a90ed7d74c8d727a%7Ctr%3Dslcc%7Csn%3D184165%7Chk%3Dd3534d5cc1b799109f52affc890ea9929ed99e20'
#
# # 바네라 여행바지 여름 밴딩 와이드 팬츠
# pd9 = 'https://smartstore.naver.com/vanera/products/401437851?NaPm=ct%3Dlufk9g8g%7Cci%3Dda14b4b5b4e4f9933788a05017ed8d02aa4dc534%7Ctr%3Dslcc%7Csn%3D174893%7Chk%3D652b64a84b053031d96ca6273ffafb3e924be28f'
#
# # 맛있닭 닭가슴살 59종 소세지 스테이크 스팀 수비드 훈제 저염 냉동 소스 헬스
# pd10 = 'https://brand.naver.com/rankingdak/products/521363595?NaPm=ct%3Dluflwis0%7Cci%3D170ec8d0ceb2d4d0ec3a94dc84a0920f16d38051%7Ctr%3Dslsf%7Csn%3D204586%7Chk%3D36069a92c17a9eb0bc270829be3bd6411646b230'
#
# # 정준산업 요술때밀이장갑 벙어리 때르메스 떼르메스
# pd11 = 'https://smartstore.naver.com/hwajanggirl/products/232021699?NaPm=ct%3Dlugvgsxk%7Cci%3D8c0e08fcda3b2ab5e527a2188b30528870508a12%7Ctr%3Dslcc%7Csn%3D156874%7Chk%3D3883607985628fa781b07625cdeb5890466f722a'
#
# # 메디힐 마스크팩 티트리 에센셜 미백 수분 보습 진정 트러블 앰플
# pd12 = 'https://smartstore.naver.com/soiskin/products/2328853532?NaPm=ct%3Dlujhsqsg%7Cci%3Ddc6b34941c3288914ab1e5e4fd1cc036a3041ae6%7Ctr%3Dslcc%7Csn%3D341129%7Chk%3D413411aae0fab9cdcac77b6928170cfb8068c673'
#
# # 층간소음 실내화 거실 실내 슬리퍼 거실화 구름슬리퍼
# pd13 = 'https://smartstore.naver.com/junretail20181112/products/5543577864?NaPm=ct%3Dluqmqfzk%7Cci%3D6a445c220b9062905bfa8721616c0ebdf05c8e44%7Ctr%3Dslcc%7Csn%3D1905546%7Chk%3D0217a28e367fd732e4da27acd2ac602153f704c2'
#
# # 아라크네 네츄럴 콤비블라인드 커튼 거실 30x30
# pd14 = 'https://brand.naver.com/aracne/products/100149718?NaPm=ct%3Dlus1z4xs%7Cci%3Db12e5db92941822e880bc77d69e3e7808624fad2%7Ctr%3Dslcc%7Csn%3D156271%7Chk%3D134450b94c52853bc49c232466ddea03eb425b78'
#
# # 1+1 친환경 호텔 지퍼형 구름 베개솜 항균 40x60 50x70 경추 피톤치드 높은 낮은
# pd15 = 'https://smartstore.naver.com/ssjg12/products/163521146?NaPm=ct%3Dlus20leo%7Cci%3D5e0763711586c9c02061e5af57e4995d30f78cd2%7Ctr%3Dslcc%7Csn%3D207313%7Chk%3D699e77d5fd217819259a4518007a3cc1e4492305'
#
# # 키네시올로지 머슬 헬스 스포츠 근육 운동 테이프 테이핑 (5CM/5M)
# pd16 = 'https://smartstore.naver.com/dlsvlslxm76/products/2342817855?NaPm=ct%3Dlusb6l1c%7Cci%3D96d2e0ed81429ebdebbae21101be3bfa98a96d15%7Ctr%3Dslcc%7Csn%3D322271%7Chk%3D3505659705f4e7427c7a13ac832d71f877e192ed'
#
# # 프릭션 슬림 지워지는 볼펜
# pd17 = 'https://smartstore.naver.com/annas_shop/products/213294700?NaPm=ct%3Dlusbba0o%7Cci%3D41465f8fdbf174bc12fa4b58b218cca4512b9aed%7Ctr%3Dslcc%7Csn%3D219059%7Chk%3Dc708b185c8d50269a83a5fcf7648a8e5ee0a5864'
#
# # 백선생 왕타칫솔 베이직10P 왕칫솔 대왕칫솔
# pd18 = 'https://brand.naver.com/wangta/products/747260037?NaPm=ct%3Dlusbeg7s%7Cci%3Db14b6f6f48e771fa06030346b54bb885aa3f7a41%7Ctr%3Dslcc%7Csn%3D509010%7Chk%3D9fd227a0c6bb596877bc50c8f55bdade18c5f96b'
#
# # 시아르더 지압슬리퍼 블랙
# pd19 = 'https://smartstore.naver.com/shardor/products/2081574784?NaPm=ct%3Dlusbg7hk%7Cci%3Da614baaaa94eb9e06e0269d250af8d2c0bf47d69%7Ctr%3Dslcc%7Csn%3D419346%7Chk%3D07355ee1587ac33239704f84b70273ed5ac6ce4c'
#
# # 유리 양념통 조미료통 - 사각 라지(L) SUGAR 양념병
# pd20 = 'https://smartstore.naver.com/romanticnovember/products/402364969?NaPm=ct%3Dlutnzpzc%7Cci%3D0dae4aa36dac4931e15ede0076103e9593190061%7Ctr%3Dslcc%7Csn%3D291723%7Chk%3Dcfdd5a748d35d7210df54815c728a87566a04365'
#
# # 여름 반팔잠옷 짱구 빅사이즈 여성 커플파자마 냉감 면홈웨어 피치기모
# pd21 = 'https://smartstore.naver.com/minnidah/products/5113653304?NaPm=ct%3Dluto2iag%7Cci%3D68c887f0c2a6e3a18f263b7249f71444d2802fff%7Ctr%3Dslcc%7Csn%3D2052478%7Chk%3D7b11e15f0a0d1cafdd539b43aafe6583a97f0afd'
#
# # 남성용 빅사이즈 밍크 극세사 수면바지 커플파자마 잠옷 딥그린
# pd22 = 'https://smartstore.naver.com/akib/products/5123361542?NaPm=ct%3Dluto3u4o%7Cci%3D5a7f76f94d38988eb53b3232cf77c9511750534a%7Ctr%3Dslcc%7Csn%3D401919%7Chk%3D7ed91a9043015c082d06259ac47b5fd36fbfda77'
#
# # 아르떼 천연비누 제로웨이스트 어성초 CP 수제 세수 세안 비누
# pd23 = 'https://smartstore.naver.com/arte24/products/4512798717?NaPm=ct%3Dluto5g00%7Cci%3D1f0d2ce009090cb7d442acdab22ee757093f95fe%7Ctr%3Dslcc%7Csn%3D775454%7Chk%3D4004f167b172ebbcf2d69519b3b81bac18e75eeb'
